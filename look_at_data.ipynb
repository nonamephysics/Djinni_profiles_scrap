# %%
import pandas as pd

# %%
df = pd.read_csv('profile.txt', sep = "\t")

# %%
df.head(15)
# Out:
#                                                 Title  \
# 0                      Data Engineer/Scala Developer
# 1                           Data Engineer with Scala
# 2                     Junior/Trainee Scala Developer
# 3         Scala Developer/Team Lead/Data Engineer/ML
# 4                 Senior Scala Developer / Tech Lead
# 5   DevOps/System Engineer | SRE | Backend Developer
# 6                                    Scala developer
# 7                                    Scala Developer
# 8                             Senior Scala Developer
# 9                                    Scala Developer
# 10                              Java/Scala Developer
# 11        Senior scala developer/Tech lead/Architect
# 12                          Scala/Big Data Developer
# 13                                   Scala Developer
# 14                                   Scala developer
#
#                        Location Salary  Experience           English  \
# ...
